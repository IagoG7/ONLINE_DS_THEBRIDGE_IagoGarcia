# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_csv("EDA/data/all_womens_foil_bout_data_May_13_2021_cleaned.csv")
df1
# Out:
#        fencer_ID  opp_ID  fencer_age  opp_age  fencer_score  opp_score  \
# 0          36796   19574          23       28             5          1
# 1          36796   42147          23       19             5          2
# 2          36796   49116          23       21             5          2
# 3          36796   39631          23       18             5          4
# 4          36796   23447          23       27             4          5
# ...          ...     ...         ...      ...           ...        ...
# 49126      45679   32336          34       25             5          2
# 49127      45679   35935          34       22             4          5
# 49128      36591   32336          22       25             2          5
# 49129      36591   35935          22       22             1          5
# 49130      32336   35935          25       22             0          5
#
#        winner_ID  fencer_curr_pts  opp_curr_pts tournament_ID  pool_ID  upset  \
# ...

# %%
df2 = pd.read_csv("EDA/data/all_womens_foil_fencer_bio_data_May_13_2021_cleaned.csv")
df2
# Out:
#          id                            name country_code       country   hand  \
# 0     28761                    DVORKIN Mary          ISR        ISRAEL   Left
# 1     43803                         SHI Yue          CHN         CHINA  Right
# 2     46080                    TANG Nga Hei          MAC  MACAO, CHINA  Right
# 3     46481  WONAME Kelsey Victoria Afriyie          GHA         GHANA  Right
# 4     47075              BRECHERET Carolina          BRA        BRAZIL  Right
# ...     ...                             ...          ...           ...    ...
# 2103  51177                    SAAVEDRA Ana          MEX        MEXICO  Right
# 2104  40429              MORE CHAVEZ Karine          CUB          CUBA  Right
# 2105  51183                    ADALID Maria          MEX        MEXICO  Right
# 2106  51186                  ESPINOSA Frida          MEX        MEXICO  Right
# 2107  51193                 MARTINEZ Maggie          MEX        MEXICO  Right
#
# ...

# %%
df3 = pd.read_csv("EDA/data/all_womens_foil_fencer_rankings_data_May_13_2021_cleaned.csv")
df3
# Out:
#           id weapon  category     season  rank  points
# 0        164   Foil  Veterans  2016/2017    78     0.0
# 1        164   Foil  Veterans  2016/2017    78     0.0
# 2        164   Foil  Veterans  2017/2018    37     0.0
# 3        164   Foil  Veterans  2017/2018    37     0.0
# 4        234   Foil    Senior  2007/2008    52    56.0
# ...      ...    ...       ...        ...   ...     ...
# 10932  53148   Foil     Cadet  2021/2022    25     0.0
# 10933  53148   Foil    Junior  2021/2022   213     2.5
# 10934  53151   Foil     Cadet  2021/2022     8     0.0
# 10935  53161   Foil    Junior  2021/2022   287     0.0
# 10936  53162   Foil    Junior  2021/2022   321     0.0
#
# [10937 rows x 6 columns]

# %%
df4 = pd.read_csv("EDA/data/all_womens_foil_tournament_data_May_13_2021_cleaned.csv")
df4
# Out:
#      competition_ID  season                                  name category  \
# 0               121    2021                            Grand Prix   Senior
# 1                41    2017                 Tournoi international   Junior
# 2               800    2015            Championnats Panaméricains   Senior
# 3               243    2019                 Championnats du Monde   Senior
# 4               237    2016  Championnats du monde juniors-cadets    Cadet
# ..              ...     ...                                   ...      ...
# 213             118    2015                        Coupe du Monde   Senior
# 214            1014    2015               Championnats asiatiques   Senior
# 215             122    2018                    Reinhold-Würth-Cup   Senior
# 216             127    2016                The Artus Court PKO BP   Senior
# 217            1218    2018                     Tournoi satellite   Senior
#
# ...
